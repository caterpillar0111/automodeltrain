# %%
import requests
from bs4 import BeautifulSoup

# %%
def crawler(word):
  

    #x = input("請輸入關鍵字：")
    # headers = {'user-agent': 'Mozilla/5.0 (Macintosh Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'}
    # html = requests.get("https://www.google.com.tw/search?q="+word+"&oq="+word+"&aqs=chrome..69i57j0l5.1211j0j7&sourceid=chrome&ie=UTF-8")
    html = requests.get("https://www.google.com.tw/search?q="+word)
    content = BeautifulSoup(html.text,"html.parser")

    # print(content)

    st1 = content.find("div",id="resultStats")
    st1 = st1.string #只取div標籤中的字串

    #print(st1)

    st1 = filter(str.isdigit, st1)
    st1 = ''.join(list(st1))
    #print(st1)

# %%
  

#x = input("請輸入關鍵字：")
# headers = {'user-agent': 'Mozilla/5.0 (Macintosh Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'}
# html = requests.get("https://www.google.com.tw/search?q="+word+"&oq="+word+"&aqs=chrome..69i57j0l5.1211j0j7&sourceid=chrome&ie=UTF-8")
html = requests.get("https://www.google.com.tw/search?q="+"dog")
content = BeautifulSoup(html.text,"html.parser")

# # print(content)

# st1 = content.find("div",id="appbar")
# st1 = st1.string #只取div標籤中的字串
items = soup.select('div.g > h3.r > a[href^="/url"]')
# #print(st1)

# st1 = filter(str.isdigit, st1)
# st1 = ''.join(list(st1))
# #print(st1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-054a127e0b2e> in <module>
#      12 # st1 = content.find("div",id="appbar")
#      13 # st1 = st1.string #只取div標籤中的字串
# ---> 14 items = soup.select('div.g > h3.r > a[href^="/url"]')
#      15 # #print(st1)
#      16
#
# NameError: name 'soup' is not defined

# %%
from selenium import webdriver
driver = webdriver.PhantomJS(executable_path=r'請輸入路徑')  # PhantomJs
driver.get("https://www.google.com.tw/search?q="+"dog")  # 輸入範例網址，交給瀏覽器 
pageSource = driver.page_source  # 取得網頁原始碼
print(pageSource)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-3f504df62b21> in <module>
# ----> 1 from selenium import webdriver
#       2 driver = webdriver.PhantomJS(executable_path=r'請輸入路徑')  # PhantomJs
#       3 driver.get("https://www.google.com.tw/search?q="+"dog")  # 輸入範例網址，交給瀏覽器
#       4 pageSource = driver.page_source  # 取得網頁原始碼
#       5 print(pageSource)
#
# ModuleNotFoundError: No module named 'selenium'

# %%
print(st1)
# Out:
# None

# %%
print(content.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="zh-TW">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    dog - Google 搜尋
#   </title>
#   <script nonce="/QhejRkiEzWskgHGLAU7bg==">
#    (function(){var a=window.performance;window.start=(new Date).getTime();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,e=c.responseStart;if(e>d&&e<=window.start){window.start=e;b.wsrt=e-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=window.google||{};google.aft=function(f){f.setAttribute("data-iml",+new Date)};}).call(this);(function(){var c=[],e=0;window.ping=function(b){-1==b.indexOf("&zx")&&(b+="&zx="+(new Date).getTime());var a=new Image,d=e++;c[d]=a;a.onerror=a.onload=a.onabort=function(){delete c[d]};a.src=b};}).call(this);
#   </script>
#   <style>
# ...

# %%
crawler('dog')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-9013c2a89c59> in <module>
# ----> 1 crawler('dog')
#
# <ipython-input-1-2f4edff9cd19> in crawler(word)
#      12
#      13     st1 = content.find("div",id="resultStats")
# ---> 14     st1 = st1.string #只取div標籤中的字串
#      15
#      16     #print(st1)
#
# AttributeError: 'NoneType' object has no attribute 'string'
